# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
df = pd.read_csv('aug_train.csv')

# %%
df

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36       1
# 1              47       0
# 2              83       0
# 3              52       1
# 4               8       0

# %%
dp = pd.read_csv('placement.csv')

# %%
dp
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
# steps 
#1. Preprocess + EDA + Featured Selection
#2. Extract input and output cols
#3. Scale the values
#4. Train test split 
#5. Train the model
#6. Evaluate the model/model selection
#7. Deploy the model

# %%
dp.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dp.shape
# Out:
# (100, 4)

# %%
ml = dp.iloc[:,1:]

# %%
ml
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
ml.shape
# Out:
# (100, 3)

# %%
plt.scatter(ml['cgpa'],ml['iq'],c=ml['placement'])

# %%
X = ml.iloc[:,0:2]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y = ml.iloc[:,-1]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 6    5.7  143.0
# 8    6.1  156.0
# 9    5.1   66.0
# 62   6.0  102.0
# 74   6.7  154.0
# ..   ...    ...
# 99   6.2  113.0
# 79   6.5   90.0
# 18   4.0  100.0
# 85   5.8  166.0
# 17   3.3  183.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 89   4.9  151.0
# 54   6.4  141.0
# 12   5.4  139.0
# 41   5.4  114.0
# 86   5.1  128.0
# 72   7.3  116.0
# 51   4.8  141.0
# 2    5.3  121.0
# 15   5.1  176.0
# 69   8.5  120.0

# %%
Y_train
# Out:
# 6     0
# 8     0
# 9     0
# 62    0
# 74    1
#      ..
# 99    1
# 79    1
# 18    0
# 85    1
# 17    0
# Name: placement, Length: 90, dtype: int64

# %%
Y_test
# Out:
# 89    0
# 54    1
# 12    0
# 41    0
# 86    0
# 72    1
# 51    0
# 2     0
# 15    0
# 69    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.273174  ,  0.50049944],
#        [ 0.07930858,  0.81549909],
#        [-0.80189786, -1.36526772],
#        [-0.00881206, -0.49296099],
#        [ 0.60803244,  0.76703761],
#        [ 0.25554987,  0.13703831],
#        [-1.24250108,  0.57319167],
#        [-1.50686302,  1.88165176],
#        [-0.00881206, -1.8741133 ],
#        [ 1.40111824, -0.80796064],
#        [ 1.84172146,  1.05780652],
#        [-1.15438044, -0.85642213],
#        [-0.71377722, -0.7837299 ],
#        [-0.97813915,  1.78472879],
#        [-2.21182817,  2.68126625],
#        [ 1.57735953, -0.20219208],
#        [-0.97813915, -1.48642143],
#        [ 0.43179116,  0.18549979],
#        [ 1.13675631, -1.75295959],
#        [ 1.13675631,  0.35511499],
#        [ 2.01796275,  1.106268  ],
#        [-0.71377722,  2.46318957],
#        [ 1.22487695,  0.23396128],
#        [-1.06625979,  1.13049874],
#        [ 0.5199118 , -0.05680763],
#        [ 0.60803244,  1.4454984 ],
#        [-0.273174  ,  0.23396128],
#        [ 1.3129976 ,  0.86396058],
#        [ 0.69615309, -0.7837299 ],
#        [-0.53753593, -0.37180728],
#        [ 0.78427373,  0.40357648],
#        [-0.62565657, -0.20219208],
#        [ 0.43179116, -2.06795924],
#        [ 0.69615309,  0.0158846 ],
#        [ 0.69615309, -0.25065357],
#        [-0.97813915,  0.28242276],
#        [ 0.87239438,  1.85742101],
#        [ 0.69615309,  0.45203796],
#        [-0.273174  ,  0.42780722],
#        [ 0.5199118 ,  0.37934573],
#        [-0.89001851, -0.75949916],
#        [ 0.07930858, -1.38949846],
#        [ 0.96051502, -1.80142108],
#        [-1.06625979,  0.98511429],
#        [ 0.25554987,  0.11280757],
#        [-1.41874237, -1.94680553],
#        [ 1.40111824,  0.13703831],
#        [-0.71377722, -0.29911505],
#        [-0.00881206,  0.04011534],
#        [-0.53753593,  0.30665351],
#        [-1.41874237,  0.6458839 ],
#        [ 0.43179116,  0.91242206],
#        [ 0.87239438, -0.25065357],
#        [ 0.25554987, -0.46873025],
#        [ 0.78427373, -0.63834545],
#        [-1.15438044, -1.70449811],
#        [-0.89001851, -0.10526911],
#        [ 0.34367051, -0.1537306 ],
#        [ 1.13675631, -0.88065287],
#        [ 1.3129976 ,  0.18549979],
#        [ 1.3129976 , -1.48642143],
#        [ 1.75360082, -1.05026806],
#        [-0.97813915, -0.05680763],
#        [-0.09693271, -0.39603802],
#        [-0.00881206,  0.6458839 ],
#        [ 0.87239438,  1.2758832 ],
#        [ 0.07930858, -1.00180658],
#        [ 0.07930858,  0.23396128],
#        [-0.71377722,  0.23396128],
#        [-1.77122495, -1.14719103],
#        [ 0.96051502,  0.69434538],
#        [-0.89001851, -1.43795994],
#        [-1.06625979, -0.25065357],
#        [ 1.84172146,  0.6458839 ],
#        [ 0.87239438,  0.40357648],
#        [-1.85934559, -0.32334579],
#        [ 0.78427373,  0.37934573],
#        [-0.18505335,  0.4762687 ],
#        [-0.97813915,  0.79126835],
#        [ 0.07930858, -0.46873025],
#        [-1.15438044, -0.03257689],
#        [-0.273174  ,  1.13049874],
#        [-0.00881206, -1.36526772],
#        [-0.71377722,  0.93665281],
#        [ 0.87239438, -1.4137292 ],
#        [ 0.16742922, -0.22642283],
#        [ 0.43179116, -0.7837299 ],
#        [-1.77122495, -0.54142248],
#        [-0.18505335,  1.05780652],
#        [-2.38806946,  1.46972914]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.79906403,  0.89781615],
#        [ 0.50375776,  0.3470087 ],
#        [-0.3647901 ,  0.23684721],
#        [-0.3647901 , -1.14017143],
#        [-0.62535446, -0.369041  ],
#        [ 1.28545083, -1.03000994],
#        [-0.88591881,  0.3470087 ],
#        [-0.45164488, -0.75460621],
#        [-0.62535446,  2.27483479],
#        [ 2.32770825, -0.80968696]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
mod_train = LogisticRegression()

# %%
#Model Training
mod_train.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = mod_train.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 0, 1])

# %%
Y_test
# Out:
# 89    0
# 54    1
# 12    0
# 41    0
# 86    0
# 72    1
# 51    0
# 2     0
# 15    0
# 69    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_pred,Y_test)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.16.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.3.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (3.10.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\adarsh\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adarsh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
plot_decision_regions(X_train,Y_train.values,clf = mod_train,legend=2)
# Out:
# <Axes: >
